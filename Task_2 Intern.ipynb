# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshchikara/Generative-AI/blob/main/Task_2_Intern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate scipy safetensors

from huggingface_hub import notebook_login
notebook_login()

from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16,
    use_safetensors=True
).to("cuda")


prompt = "cyberpunk cat with neon eyes"
image = pipe(prompt).images[0]
display(image)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
